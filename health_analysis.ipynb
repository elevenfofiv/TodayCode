# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('./Data/NHIS_OPEN_GJ_2017_v1.1.csv', encoding='cp949')
df.shape
# Out:
# (1000000, 34)

# %%
df.head()
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 0  2017        1     1            8    43        170         75  90.0    1.0
# 1  2017        2     1            7    11        180         80  89.0    0.9
# 2  2017        3     1            9    41        165         75  91.0    1.2
# 3  2017        4     1           11    48        175         80  91.0    1.5
# 4  2017        5     1           11    30        165         60  80.0    1.0
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    1.0  ...   40.0   1.0     Y         Y      NaN    NaN      NaN
# 1    1.2  ...   27.0   3.0     N         Y      NaN    NaN      NaN
# 2    1.5  ...   68.0   1.0     N         N      NaN    NaN      NaN
# 3    1.2  ...   18.0   1.0     N         Y      NaN    NaN      NaN
# 4    1.2  ...   25.0   1.0     N         Y      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석     데이터공개일자
# 0           NaN    Y  2018-11-26
# ...

# %%
df.tail()
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 999995  2017   999996     1           10    48        175         80  92.1
# 999996  2017   999997     1            8    41        170         75  86.0
# 999997  2017   999998     2            9    26        155         50  68.0
# 999998  2017   999999     1            6    29        175         60  72.0
# 999999  2017  1000000     1           11    41        160         70  90.5
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  \
# 999995    1.5    1.5  ...   27.0   1.0     N         N      NaN    NaN
# 999996    1.0    1.5  ...   15.0   1.0     N         N      NaN    NaN
# 999997    1.0    0.7  ...   17.0   3.0     Y         N      NaN    NaN
# 999998    1.5    1.0  ...   17.0   1.0     N         N      NaN    NaN
# 999999    1.0    1.5  ...   36.0   3.0     Y         N      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석     데이터공개일자
# ...

# %%
df.sample()
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 189118  2017   189119     2           11    11        155         50  65.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  \
# 189118    1.2    1.2  ...   15.0   1.0     N         Y      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상  치석     데이터공개일자
# 189118      NaN           NaN   N  2018-11-26
#
# [1 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 34 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   기준년도          1000000 non-null  int64
#  1   가입자일련번호       1000000 non-null  int64
#  2   성별코드          1000000 non-null  int64
#  3   연령대코드(5세단위)   1000000 non-null  int64
#  4   시도코드          1000000 non-null  int64
#  5   신장(5Cm단위)     1000000 non-null  int64
#  6   체중(5Kg단위)     1000000 non-null  int64
#  7   허리둘레          999734 non-null   float64
#  8   시력(좌)         999817 non-null   float64
#  9   시력(우)         999811 non-null   float64
#  10  청력(좌)         999842 non-null   float64
#  11  청력(우)         999844 non-null   float64
#  12  수축기혈압         999981 non-null   float64
#  13  이완기혈압         999982 non-null   float64
#  14  식전혈당(공복혈당)    999958 non-null   float64
#  15  총콜레스테롤        999957 non-null   float64
#  16  트리글리세라이드      999955 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상', '치석',
#        '데이터공개일자'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 기준년도              int64
# 가입자일련번호           int64
# 성별코드              int64
# 연령대코드(5세단위)       int64
# 시도코드              int64
# 신장(5Cm단위)         int64
# 체중(5Kg단위)         int64
# 허리둘레            float64
# 시력(좌)           float64
# 시력(우)           float64
# 청력(좌)           float64
# 청력(우)           float64
# 수축기혈압           float64
# 이완기혈압           float64
# 식전혈당(공복혈당)      float64
# 총콜레스테롤          float64
# 트리글리세라이드        float64
# HDL콜레스테롤        float64
# LDL콜레스테롤        float64
# 혈색소             float64
# 요단백             float64
# 혈청크레아티닌         float64
# (혈청지오티)AST      float64
# (혈청지오티)ALT      float64
# 감마지티피           float64
# 흡연상태            float64
# 음주여부             object
# 구강검진수검여부         object
# 치아우식증유무         float64
# 결손치유무           float64
# 치아마모증유무         float64
# 제3대구치(사랑니)이상    float64
# 치석               object
# 데이터공개일자          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)             0
# 체중(5Kg단위)             0
# 허리둘레                266
# 시력(좌)               183
# 시력(우)               189
# 청력(좌)               158
# 청력(우)               156
# 수축기혈압                19
# 이완기혈압                18
# 식전혈당(공복혈당)           42
# 총콜레스테롤               43
# 트리글리세라이드             45
# HDL콜레스테롤             44
# LDL콜레스테롤           2912
# 혈색소                  52
# 요단백                4592
# 혈청크레아티닌              43
# (혈청지오티)AST           41
# (혈청지오티)ALT           42
# 감마지티피                42
# 흡연상태                144
# 음주여부                536
# 구강검진수검여부              0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               621422
# 데이터공개일자               0
# dtype: int64

# %%
df.isna().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)             0
# 체중(5Kg단위)             0
# 허리둘레                266
# 시력(좌)               183
# 시력(우)               189
# 청력(좌)               158
# 청력(우)               156
# 수축기혈압                19
# 이완기혈압                18
# 식전혈당(공복혈당)           42
# 총콜레스테롤               43
# 트리글리세라이드             45
# HDL콜레스테롤             44
# LDL콜레스테롤           2912
# 혈색소                  52
# 요단백                4592
# 혈청크레아티닌              43
# (혈청지오티)AST           41
# (혈청지오티)ALT           42
# 감마지티피                42
# 흡연상태                144
# 음주여부                536
# 구강검진수검여부              0
# 치아우식증유무         1000000
# 결손치유무           1000000
# 치아마모증유무         1000000
# 제3대구치(사랑니)이상    1000000
# 치석               621422
# 데이터공개일자               0
# dtype: int64

# %%
df.isnull().sum().plot.barh(figsize=(10, 9))
# Out:
# <AxesSubplot:>

# %%
df[["(혈청지오티)ALT", "(혈청지오티)AST"]].head()
# Out:
#    (혈청지오티)ALT  (혈청지오티)AST
# 0        35.0        21.0
# 1        36.0        20.0
# 2        32.0        47.0
# 3        34.0        29.0
# 4        12.0        19.0

# %%
df[["(혈청지오티)ALT", "(혈청지오티)AST"]].describe()
# Out:
#           (혈청지오티)ALT     (혈청지오티)AST
# count  999958.000000  999959.000000
# mean       25.749509      25.994671
# std        26.294770      23.587469
# min         1.000000       1.000000
# 25%        15.000000      19.000000
# 50%        20.000000      23.000000
# 75%        29.000000      28.000000
# max      7210.000000    9999.000000

# %%
df[["성별코드"]].value_counts()
# Out:
# 성별코드
# 1       530410
# 2       469590
# dtype: int64

# %%
df[["흡연상태"]].value_counts()
# Out:
# 흡연상태
# 1.0     607942
# 3.0     215702
# 2.0     176212
# dtype: int64

# %%
df.groupby(['성별코드'])['가입자일련번호'].count()
# Out:
# 성별코드
# 1    530410
# 2    469590
# Name: 가입자일련번호, dtype: int64

# %%
df.groupby(['성별코드', '흡연상태'])['가입자일련번호'].count()
# Out:
# 성별코드  흡연상태
# 1     1.0     165904
#       2.0     165186
#       3.0     199277
# 2     1.0     442038
#       2.0      11026
#       3.0      16425
# Name: 가입자일련번호, dtype: int64

# %%
df.groupby(['성별코드', '음주여부'])['감마지티피'].mean()
# Out:
# 성별코드  음주여부
# 1     N       34.739868
#       Y       56.610981
# 2     N       22.612408
#       Y       25.001018
# Name: 감마지티피, dtype: float64

# %%
df.groupby(['성별코드', '음주여부'])['감마지티피'].describe()
# Out:
#               count       mean        std  min   25%   50%   75%    max
# 성별코드 음주여부
# 1    N     173604.0  34.739868  37.606197  1.0  18.0  25.0  38.0  999.0
#      Y     356576.0  56.610981  68.851128  1.0  24.0  37.0  63.0  999.0
# 2    N     326813.0  22.612408  25.203579  1.0  13.0  17.0  24.0  999.0
#      Y     142429.0  25.001018  36.725100  1.0  13.0  17.0  25.0  999.0

# %%
df.groupby(['성별코드', '음주여부'])['감마지티피'].agg(["count", "mean", "median"])
# Out:
#             count       mean  median
# 성별코드 음주여부
# 1    N     173604  34.739868    25.0
#      Y     356576  56.610981    37.0
# 2    N     326813  22.612408    17.0
#      Y     142429  25.001018    17.0

# %%
df.pivot_table(index="음주여부", values="가입자일련번호", aggfunc="count")
# Out:
#       가입자일련번호
# 음주여부
# N      500439
# Y      499025

# %%
pd.pivot_table(df, index="음주여부", values="감마지티피", 
    aggfunc=["mean", "median"])
# Out:
#            mean median
#           감마지티피  감마지티피
# 음주여부
# N     26.819650   19.0
# Y     47.588675   30.0

# %%
pd.pivot_table(df, index=["성별코드", "음주여부"], values="감마지티피", 
    aggfunc="describe")
# Out:
#             25%   50%   75%     count    max       mean  min        std
# 성별코드 음주여부
# 1    N     18.0  25.0  38.0  173604.0  999.0  34.739868  1.0  37.606197
#      Y     24.0  37.0  63.0  356576.0  999.0  56.610981  1.0  68.851128
# 2    N     13.0  17.0  24.0  326813.0  999.0  22.612408  1.0  25.203579
#      Y     13.0  17.0  25.0  142429.0  999.0  25.001018  1.0  36.725100

# %%
h = df.hist(figsize=(12, 12))

# %%
h = df.iloc[:, :12].hist(figsize=(12, 12))

# %%
h = df.iloc[:, 12:24].hist(figsize=(24, 24), bins=100)

# %%
h = df.iloc[:, 24:].hist(figsize=(12, 12), bins=100)

# %%
df_sample = df.sample(1000, random_state=1)
df_sample.shape
# Out:
# (1000, 34)

# %%
df["음주여부"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="음주여부", data=df)
# Out:
# <AxesSubplot:xlabel='음주여부', ylabel='count'>

# %%
sns.countplot(x="음주여부", data=df, hue="성별코드")
# Out:
# <AxesSubplot:xlabel='음주여부', ylabel='count'>

# %%
sns.countplot(x="연령대코드(5세단위)", data=df, hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='count'>

# %%
plt.figure(figsize=(20, 20))
sns.countplot(data=df, x="신장(5Cm단위)")
# Out:
# <AxesSubplot:xlabel='신장(5Cm단위)', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x="신장(5Cm단위)", hue="성별코드")
# Out:
# <AxesSubplot:xlabel='신장(5Cm단위)', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x="체중(5Kg단위)", hue="성별코드")
# Out:
# <AxesSubplot:xlabel='체중(5Kg단위)', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df, x="체중(5Kg단위)", hue="음주여부")
# Out:
# <AxesSubplot:xlabel='체중(5Kg단위)', ylabel='count'>

# %%
plt.figure(figsize=(14, 5))
sns.barplot(data=df_sample, x="연령대코드(5세단위)", y="총콜레스테롤", hue="흡연상태")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='총콜레스테롤'>

# %%
plt.figure(figsize=(14, 5))
sns.barplot(data=df, x="연령대코드(5세단위)", y="트리글리세라이드", hue="음주여부", ci=None)
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='트리글리세라이드'>

# %%
plt.figure(figsize=(14, 5))
sns.barplot(data=df_sample, x="연령대코드(5세단위)", y="체중(5Kg단위)", hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='체중(5Kg단위)'>

# %%
plt.figure(figsize=(14, 5))
sns.lineplot(data=df_sample, x="연령대코드(5세단위)", y="체중(5Kg단위)", hue="성별코드")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='체중(5Kg단위)'>

# %%
plt.figure(figsize=(14, 5))
sns.lineplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="성별코드")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='신장(5Cm단위)'>

# %%
plt.figure(figsize=(14, 5))
sns.lineplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='신장(5Cm단위)'>

# %%
plt.figure(figsize=(14, 5))
sns.barplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="음주여부")
sns.pointplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='신장(5Cm단위)'>

# %%
plt.figure(figsize=(14, 5))
# sns.barplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="음주여부")
sns.pointplot(data=df_sample, x="연령대코드(5세단위)", y="신장(5Cm단위)", hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='신장(5Cm단위)'>

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(data=df, x="연령대코드(5세단위)", y="혈색소", ci=None, hue="음주여부")
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='혈색소'>

# %%
plt.figure(figsize=(15, 4))
sns.boxplot(data=df, x="신장(5Cm단위)", y="체중(5Kg단위)", hue="성별코드")
# Out:
# <AxesSubplot:xlabel='신장(5Cm단위)', ylabel='체중(5Kg단위)'>

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(data=df_sample, x="신장(5Cm단위)", y="체중(5Kg단위)", hue="음주여부",split=True)
# Out:
# <AxesSubplot:xlabel='신장(5Cm단위)', ylabel='체중(5Kg단위)'>

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(data=df_sample, x="연령대코드(5세단위)", y="혈색소", hue="음주여부",split=True)
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='혈색소'>

# %%
plt.figure(figsize=(15, 4))
sns.swarmplot(data=df_sample, x="신장(5Cm단위)", y="체중(5Kg단위)", hue="음주여부")
# Out:
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(15, 4))
sns.swarmplot(data=df_sample, x="연령대코드(5세단위)", y="혈색소", hue="음주여부")
# Out:
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.lmplot(data=df_sample, x="연령대코드(5세단위)", y='혈색소', hue='음주여부', col='성별코드')

# %%
plt.figure(figsize=(15, 4))
sns.scatterplot(data=df_sample, x="(혈청지오티)AST", y="(혈청지오티)ALT", hue="허리둘레", size="체중(5Kg단위)")
# Out:
# <AxesSubplot:xlabel='(혈청지오티)AST', ylabel='(혈청지오티)ALT'>

# %%
plt.figure(figsize=(15,8))
sns.lmplot(data=df_sample, x="신장(5Cm단위)", y="체중(5Kg단위)", hue="성별코드", col="음주여부")

# %%
plt.figure(figsize=(15, 4))
sns.lmplot(data=df_sample, x="(혈청지오티)AST", y="(혈청지오티)ALT", hue="흡연상태", col="음주여부")

# %%
plt.figure(figsize=(15, 4))
sns.lmplot(data=df_sample, x="수축기혈압", y="이완기혈압", hue="음주여부")

# %%
plt.figure(figsize=(15, 4))
sns.lmplot(data=df_sample, x="(혈청지오티)AST", y="(혈청지오티)ALT", hue="음주여부", robust=True)

# %%
df_ASLT = df_sample[(df_sample["(혈청지오티)AST"] < 100) & (df_sample["(혈청지오티)ALT"] < 100)]

# %%
plt.figure(figsize=(15, 4))
sns.lmplot(data=df_ASLT, x="(혈청지오티)AST", y="(혈청지오티)ALT", hue="음주여부", ci=None)

# %%
df_ASLT_high = df[(df["(혈청지오티)AST"] > 400) | (df["(혈청지오티)ALT"] > 400)]

# %%
df_ASLT_high
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)   허리둘레  \
# 4754    2017     4755     1            9    41        170         55   74.0
# 15820   2017    15821     2           13    45        150         55   83.0
# 17830   2017    17831     2            8    41        150         50   64.6
# 19949   2017    19950     1            6    41        170        105  103.0
# 26464   2017    26465     1            7    41        175         70   82.0
# ...      ...      ...   ...          ...   ...        ...        ...    ...
# 982305  2017   982306     2           16    28        155         50   79.3
# 990867  2017   990868     2           11    41        145         45   75.0
# 991226  2017   991227     1            6    42        170         80   81.0
# 992747  2017   992748     2           10    41        165         40   58.0
# 995323  2017   995324     1            7    11        185        105  101.4
#
# ...

# %%
plt.figure(figsize=(15, 4))
sns.lmplot(data=df_ASLT_high, x="(혈청지오티)AST", y="(혈청지오티)ALT", hue="음주여부", ci=None)

# %%
df_ASLT_high_8000 = df_ASLT_high[df_ASLT_high["(혈청지오티)AST"] > 8000]
df_ASLT_high_8000.iloc[:, 10:27]
# Out:
#         청력(좌)  청력(우)  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  트리글리세라이드  HDL콜레스테롤  \
# 541757    1.0    1.0   96.0   74.0        93.0   161.0      67.0      78.0
#
#         LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태 음주여부
# 541757      69.0  15.4  1.0      1.2      9999.0       380.0  419.0   3.0    Y

# %%
df.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상', '치석',
#        '데이터공개일자'],
#       dtype='object')

# %%
plt.figure(figsize=(15,4))
sns.distplot(df["총콜레스테롤"], bins=100)
# Out:
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='Density'>

# %%
df_chol = df.loc[df["총콜레스테롤"].notnull(), "총콜레스테롤"]

# %%
df_chol
# Out:
# 0         193.0
# 1         228.0
# 2         136.0
# 3         201.0
# 4         199.0
#           ...
# 999995    198.0
# 999996    133.0
# 999997    205.0
# 999998    122.0
# 999999    225.0
# Name: 총콜레스테롤, Length: 999957, dtype: float64

# %%
plt.figure(figsize=(15,4))
sns.distplot(df_chol)
# Out:
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='Density'>

# %%
df_chol.describe()
# Out:
# count    999957.000000
# mean        195.548251
# std          38.718205
# min          30.000000
# 25%         169.000000
# 50%         193.000000
# 75%         219.000000
# max        2344.000000
# Name: 총콜레스테롤, dtype: float64

# %%
df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 0       2017        1     1            8    43        170         75  90.0
# 1       2017        2     1            7    11        180         80  89.0
# 2       2017        3     1            9    41        165         75  91.0
# 3       2017        4     1           11    48        175         80  91.0
# 4       2017        5     1           11    30        165         60  80.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999995  2017   999996     1           10    48        175         80  92.1
# 999996  2017   999997     1            8    41        170         75  86.0
# 999997  2017   999998     2            9    26        155         50  68.0
# 999998  2017   999999     1            6    29        175         60  72.0
# 999999  2017  1000000     1           11    41        160         70  90.5
#
# ...

# %%
df[df["총콜레스테롤"].notnull() & (df["음주여부"] == 'Y')]
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 0       2017        1     1            8    43        170         75  90.0
# 5       2017        6     1           11    41        165         55  75.0
# 7       2017        8     1            8    48        175         65  84.2
# 8       2017        9     1           12    41        170         75  84.0
# 9       2017       10     1            9    41        175         75  82.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999990  2017   999991     1           17    11        170         60  74.0
# 999992  2017   999993     1            5    11        175         65  74.5
# 999993  2017   999994     1           15    42        165         60  78.0
# 999997  2017   999998     2            9    26        155         50  68.0
# 999999  2017  1000000     1           11    41        160         70  90.5
#
# ...

# %%
df.loc[df["총콜레스테롤"].notnull() & (df["음주여부"] == 'Y'), "총콜레스테롤"]
# Out:
# 0         193.0
# 5         218.0
# 7         185.0
# 8         217.0
# 9         195.0
#           ...
# 999990    171.0
# 999992    211.0
# 999993    167.0
# 999997    205.0
# 999999    225.0
# Name: 총콜레스테롤, Length: 499004, dtype: float64

# %%
sns.distplot(df.loc[df["총콜레스테롤"].notnull() & (df["음주여부"] == 'Y'), "총콜레스테롤"], hist=False)
sns.distplot(df.loc[df["총콜레스테롤"].notnull() & (df["음주여부"] == 'N'), "총콜레스테롤"], hist=False)
# Out:
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Miniconda3\envs\my_env_39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='총콜레스테롤', ylabel='Density'>

# %%
df_sample
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)   허리둘레  \
# 276826  2017   276827     1           12    41        160         55   77.0
# 849425  2017   849426     1            9    31        170         75   89.9
# 504499  2017   504500     1            8    42        170         75   86.3
# 601054  2017   601055     1           14    31        170         70   84.0
# 980221  2017   980222     1           17    41        160         60   86.0
# ...      ...      ...   ...          ...   ...        ...        ...    ...
# 890013  2017   890014     2            8    41        155         80   98.0
# 875389  2017   875390     1           11    41        170         60   81.0
# 358458  2017   358459     1            9    11        170         90  101.0
# 808228  2017   808229     1           11    28        160         65   85.0
# 317698  2017   317699     1            9    41        165         85  100.0
#
# ...

# %%
columns = ["연령대코드(5세단위)", "체중(5Kg단위)", "신장(5Cm단위)", "허리둘레", "시력(좌)", "시력(우)", "청력(좌)", "청력(우)", "수축기혈압", "이완기혈압", "식전혈당(공벅혈당)",
"총콜레스테롤", "트리글리세라이드", "HDL콜레스토롤","LDL콜레스테롤", "혈색소", "요단백", "혈청클레아티닌", "(혈청지오디)AST", "(혈청지오디)ALT","감마지티피","흡연상테", "음주여부"]
columns
# Out:
# ['연령대코드(5세단위)',
#  '체중(5Kg단위)',
#  '신장(5Cm단위)',
#  '허리둘레',
#  '시력(좌)',
#  '시력(우)',
#  '청력(좌)',
#  '청력(우)',
#  '수축기혈압',
#  '이완기혈압',
#  '식전혈당(공벅혈당)',
#  '총콜레스테롤',
#  '트리글리세라이드',
#  'HDL콜레스토롤',
#  'LDL콜레스테롤',
#  '혈색소',
#  '요단백',
#  '혈청클레아티닌',
#  '(혈청지오디)AST',
#  '(혈청지오디)ALT',
#  '감마지티피',
#  '흡연상테',
#  '음주여부']

# %%
df_sample
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)   허리둘레  \
# 276826  2017   276827     1           12    41        160         55   77.0
# 849425  2017   849426     1            9    31        170         75   89.9
# 504499  2017   504500     1            8    42        170         75   86.3
# 601054  2017   601055     1           14    31        170         70   84.0
# 980221  2017   980222     1           17    41        160         60   86.0
# ...      ...      ...   ...          ...   ...        ...        ...    ...
# 890013  2017   890014     2            8    41        155         80   98.0
# 875389  2017   875390     1           11    41        170         60   81.0
# 358458  2017   358459     1            9    11        170         90  101.0
# 808228  2017   808229     1           11    28        160         65   85.0
# 317698  2017   317699     1            9    41        165         85  100.0
#
# ...

# %%
df_small = df.sample[columns]
df_corr = df.small.corr()
df_corr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ELEVEN~1\AppData\Local\Temp/ipykernel_2828/2918868737.py in <module>
# ----> 1 df_small = df.sample[columns]
#       2 df_corr = df.small.corr()
#       3 df_corr
#
# TypeError: 'method' object is not subscriptable
